# %%
import sys
sys.path.append('/public/workspace/ruru_97/projects/schgnn/csMAHN')
from test_csMAHN import test_scMAHN

# %%
test_scMAHN(  tissue = "testis",
            gse_ids = ["GSE142585","GSE142585"],
            species = ('human', 'macaque'),
            dsnames = ('human', 'macaque'))
test_scMAHN(  reverse=True,
            tissue = "testis",
            gse_ids = ["GSE142585","GSE142585"],
            species = ('human', 'macaque'),
            dsnames = ('human', 'macaque'))
# Out:
# /public/workspace/ruru_97/projects/schgnn/result/testis/testis-GSE142585_human-GSE142585_macaque-03-06-17.38.12/model_/mutistages
# ----raw----
#                 reference  query
# cell_type
# RoundSpermatid       3185   2945
# Elongating           2516  11644
# Spermatocyte         2247   3731
# Spermatogonia        2167   1156
# Myoid                2121    362
# ImmLeydig             519   1366
# m-Pericyte            410    116
# Endothelial           297    178
# Macrophage            231     17
# f-Pericyte             79     39
# Tcell                  65     20
# ----new----
#                 reference  query
# cell_type
# RoundSpermatid       3185   2945
# Elongating           2516  11644
# Spermatocyte         2247   3731
# Spermatogonia        2167   1156
# Myoid                2121    362
# ImmLeydig             519   1366
# m-Pericyte            410    116
# Endothelial           297    178
# Macrophage            231     17
# f-Pericyte             79     39
# ...

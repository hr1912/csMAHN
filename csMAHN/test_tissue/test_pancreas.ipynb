# %%
import sys
sys.path.append('/public/workspace/ruru_97/projects/schgnn/csMAHN')
import test_csMAHN as testa
import importlib as im
im.reload(testa)
# Out:
# <module 'test_csMAHN' from '/public/workspace/ruru_97/projects/schgnn/csMAHN/test_csMAHN.py'>

# %%
testa.test_scMAHN(
tissue = "retinal",
            gse_ids = ["jiewang","jiewang"],
            species = ('zebrafish', 'mouse'),
            dsnames = ('zebrafish_ld_mean', 'mouse_ld_mean')
)
# Out:
# /public/workspace/ruru_97/projects/schgnn/result/retinal/retinal-jiewang_zebrafish_ld_mean-jiewang_mouse_ld_mean-03-06-23.17.22/model_/mutistages
# ----raw----
#                   reference   query
# Resting MG           7738.0  5142.0
# Rods                 7294.0  6941.0
# Activated MG         6905.0  2014.0
# HC                   5083.0   335.0
# Cones                4197.0  1570.0
# GABAergic AC         3078.0  4640.0
# RGC                  2789.0   761.0
# Microglia            2520.0   265.0
# BC                   1532.0     NaN
# Glycinergic AC       1422.0   864.0
# Pericytes             916.0   194.0
# Progenitors           446.0     NaN
# V/E cells             427.0   224.0
# RPE                   422.0   333.0
# Oligodendrocytes      384.0     NaN
# Rod BC                  NaN  6727.0
# ON cone BC              NaN  6572.0
# OFF cone BC             NaN  4027.0
# Astrocytes              NaN   208.0
# Reticulocytes           NaN    43.0
# ----new----
# ...

# %%
test_scMAHN()
test_scMAHN(reverse=True)
# Out:
# /public/workspace/ruru_97/projects/schgnn/result/pancreas/pancreas-GSE84113_human-GSE84113_mouse-03-06-17.18.13/model_/mutistages
# ----raw----
#                     reference  query
# cell_type
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# ----new----
#                     reference  query
# cell_type
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# ...

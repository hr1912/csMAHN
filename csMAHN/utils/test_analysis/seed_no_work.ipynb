# %%
from test_csMAHN import test_scMAHN

# %%
test_scMAHN()
# Out:
# /public/workspace/ruru_97/projects/schgnn/result/pancreas/pancreas-GSE84113_human-GSE84113_mouse-03-01-19.09.59/model_/mutistages
# ----raw----
#                     reference  query
# cell_type
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# ----new----
#                     reference  query
# cell_type
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# ...

# %%
test_scMAHN()
# Out:
# /public/workspace/ruru_97/projects/schgnn/result/pancreas/pancreas-GSE84113_human-GSE84113_mouse-02-29-05.22.39/model_/mutistages
# ----raw----
#                     reference  query
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# ----new----
#                     reference  query
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# Task: refernece:GSE84113_human 7264 cells x 7264 gene -> query:GSE84113_mouse 1841 cells x 20125 gene in pancreas
# ...

# %%
test_scMAHN()
# Out:
# /public/workspace/ruru_97/projects/schgnn/result/pancreas/pancreas-GSE84113_human-GSE84113_mouse-02-29-05.24.32/model_/mutistages
# ----raw----
#                     reference  query
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# ----new----
#                     reference  query
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# Task: refernece:GSE84113_human 7264 cells x 7264 gene -> query:GSE84113_mouse 1841 cells x 20125 gene in pancreas
# ...

# %%
test_scMAHN()
# Out:
# /public/workspace/ruru_97/projects/schgnn/result/pancreas/pancreas-GSE84113_human-GSE84113_mouse-02-29-05.26.24/model_/mutistages
# ----raw----
#                     reference  query
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# ----new----
#                     reference  query
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# Task: refernece:GSE84113_human 7264 cells x 7264 gene -> query:GSE84113_mouse 1841 cells x 20125 gene in pancreas
# ...

# %%
test_scMAHN()
# Out:
# /public/workspace/ruru_97/projects/schgnn/result/pancreas/pancreas-GSE84113_human-GSE84113_mouse-02-29-05.28.10/model_/mutistages
# ----raw----
#                     reference  query
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# ----new----
#                     reference  query
# beta                     2525    894
# alpha                    2326    191
# ductal                   1077    275
# delta                     601    218
# gamma                     255     41
# endothelial               252    139
# quiescent_stellate        173     47
# macrophage                 55     36
# Task: refernece:GSE84113_human 7264 cells x 7264 gene -> query:GSE84113_mouse 1841 cells x 20125 gene in pancreas
# ...
